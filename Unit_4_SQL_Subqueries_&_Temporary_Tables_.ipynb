# %% [markdown]
# <a href="https://colab.research.google.com/github/YahiaML/SQL_Udacity_Course/blob/main/Unit_4_SQL_Subqueries_%26_Temporary_Tables_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# %%
db = sqlite3.connect('/content/parch_and_posey.db')

# %% [markdown]
# # **L_1:** Introduction to Subqueries

# %% [markdown]
# can not run the code below because we used date_trunc function

# %%
#SELECT *
#FROM
#( SELECT channel, DATE_TRUNC('day', occurred_at) day_, count(*) Num_of_events
#FROM web_events
#GROUP BY 1,2
#ORDER BY 3 DESC) t1

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
#SELECT channel, AVG(Num_of_events)
#FROM
#( SELECT channel, DATE_TRUNC('day', occurred_at) day_, count(*) Num_of_events
#FROM web_events
#GROUP BY 1,2) t1
#GROUP BY 1
#ORDER BY 2 DESC

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
#SELECT AVG(standard_qty) avg_standard_paper, AVG(gloss_qty) avg_gloss_paper, AVG(poster_qty) avg_poster_paper, SUM(total_amt_usd) AS total 
#FROM orders
#WHERE DATE_TRUNC('month', occurred_at) = 
#     (SELECT DATE_TRUNC('month', MIN(occurred_at)) FROM orders)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)
